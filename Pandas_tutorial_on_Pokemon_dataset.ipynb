# %%
import pandas as pd
import missingno as msn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Pokemon.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.rename(columns={'#':'Number'}, inplace=True)

# %%
df.head()
# Out:
#    Number                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur  Grass  Poison    318  45      49       49
# 1       2                Ivysaur  Grass  Poison    405  60      62       63
# 2       3               Venusaur  Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4       4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Number      800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.shape
# Out:
# (800, 13)

# %%
df.isnull().sum()
# Out:
# Number          0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
msn.matrix(df)
plt.show()

# %%
msn.bar(df)
plt.show()

# %%
df['Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Type 1', 'Type 2']]
# Out:
#       Type 1  Type 2
# 0      Grass  Poison
# 1      Grass  Poison
# 2      Grass  Poison
# 3      Grass  Poison
# 4       Fire     NaN
# ..       ...     ...
# 795     Rock   Fairy
# 796     Rock   Fairy
# 797  Psychic   Ghost
# 798  Psychic    Dark
# 799     Fire   Water
#
# [800 rows x 2 columns]

# %%
df.describe().T
# Out:
#             count       mean         std    min     25%    50%     75%    max
# Number      800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %%
df.describe(include=['object']).T
# Out:
#        count unique        top freq
# Name     800    800  Bulbasaur    1
# Type 1   800     18      Water  112
# Type 2   414     18     Flying   97

# %%
df['HP']>80
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: HP, Length: 800, dtype: bool

# %%
df[df['HP']>80]
# Out:
#      Number                 Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 22       18              Pidgeot  Normal  Flying    479   83      80       75
# 23       18  PidgeotMega Pidgeot  Normal  Flying    579   83      80       80
# 36       31            Nidoqueen  Poison  Ground    505   90      92       87
# 39       34             Nidoking  Poison  Ground    505   81     102       77
# 41       36             Clefable   Fairy     NaN    483   95      70       73
# ..      ...                  ...     ...     ...    ...  ...     ...      ...
# 789     713              Avalugg     Ice     NaN    514   95     117      184
# 791     715              Noivern  Flying  Dragon    535   85      70       80
# 792     716              Xerneas   Fairy     NaN    680  126     131       95
# 793     717              Yveltal    Dark  Flying    680  126     131       95
# 794     718     Zygarde50% Forme  Dragon  Ground    600  108     100      121
#
# ...

# %%
df[df['HP']>80]['HP']
# Out:
# 22      83
# 23      83
# 36      90
# 39      81
# 41      95
#       ...
# 789     95
# 791     85
# 792    126
# 793    126
# 794    108
# Name: HP, Length: 193, dtype: int64

# %%
df[df['HP']>80][['HP', 'Type 1']]
# Out:
#       HP  Type 1
# 22    83  Normal
# 23    83  Normal
# 36    90  Poison
# 39    81  Poison
# 41    95   Fairy
# ..   ...     ...
# 789   95     Ice
# 791   85  Flying
# 792  126   Fairy
# 793  126    Dark
# 794  108  Dragon
#
# [193 rows x 2 columns]

# %%
df[(df['HP']>80) & (df['Type 1']=='Water') ]
# Out:
#      Number                   Name Type 1    Type 2  Total   HP  Attack  \
# 67       62              Poliwrath  Water  Fighting    510   90      95
# 85       79               Slowpoke  Water   Psychic    315   90      65
# 86       80                Slowbro  Water   Psychic    490   95      75
# 87       80    SlowbroMega Slowbro  Water   Psychic    590   95      75
# 94       87                Dewgong  Water       Ice    475   90      70
# 140     130               Gyarados  Water    Flying    540   95     125
# 141     130  GyaradosMega Gyarados  Water      Dark    640   95     155
# 142     131                 Lapras  Water       Ice    535  130      85
# 145     134               Vaporeon  Water       NaN    525  130      65
# 174     160             Feraligatr  Water       NaN    530   85     105
# 185     171                Lanturn  Water  Electric    460  125      58
# 199     184              Azumarill  Water     Fairy    420  100      50
# ...

# %%
df[(df['HP']>80) | (df['Type 1']=='Water') ]
# Out:
#      Number                     Name  Type 1  Type 2  Total   HP  Attack  \
# 9         7                 Squirtle   Water     NaN    314   44      48
# 10        8                Wartortle   Water     NaN    405   59      63
# 11        9                Blastoise   Water     NaN    530   79      83
# 12        9  BlastoiseMega Blastoise   Water     NaN    630   79     103
# 22       18                  Pidgeot  Normal  Flying    479   83      80
# ..      ...                      ...     ...     ...    ...  ...     ...
# 789     713                  Avalugg     Ice     NaN    514   95     117
# 791     715                  Noivern  Flying  Dragon    535   85      70
# 792     716                  Xerneas   Fairy     NaN    680  126     131
# 793     717                  Yveltal    Dark  Flying    680  126     131
# 794     718         Zygarde50% Forme  Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[(df['HP']>80) & (df['Type 1']=='Water') ][['HP', 'Type 1']]
# Out:
#       HP Type 1
# 67    90  Water
# 85    90  Water
# 86    95  Water
# 87    95  Water
# 94    90  Water
# 140   95  Water
# 141   95  Water
# 142  130  Water
# 145  130  Water
# 174   85  Water
# 185  125  Water
# 199  100  Water
# 201   90  Water
# 210   95  Water
# 214   95  Water
# 264  100  Water
# 282  100  Water
# 283  100  Water
# 350  130  Water
# 351  170  Water
# 372  110  Water
# 382   95  Water
# 404  100  Water
# 421  100  Water
# 422  100  Water
# 440   84  Water
# 466   85  Water
# 470  111  Water
# 541   90  Water
# 548  100  Water
# 562   95  Water
# 597  105  Water
# 654  100  Water
# 655  165  Water
# 713   91  Water
# 714   91  Water

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df['Type 1'].value_counts(normalize=True)
# Out:
# Water       0.14000
# Normal      0.12250
# Grass       0.08750
# Bug         0.08625
# Psychic     0.07125
# Fire        0.06500
# Electric    0.05500
# Rock        0.05500
# Dragon      0.04000
# Ground      0.04000
# Ghost       0.04000
# Dark        0.03875
# Poison      0.03500
# Steel       0.03375
# Fighting    0.03375
# Ice         0.03000
# Fairy       0.02125
# Flying      0.00500
# Name: Type 1, dtype: float64

# %%
df.loc[:, 'Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.loc[1:5, 'Type 1']
# Out:
# 1    Grass
# 2    Grass
# 3    Grass
# 4     Fire
# 5     Fire
# Name: Type 1, dtype: object

# %%
df.loc[:, 'Type 1': 'HP']
# Out:
#       Type 1  Type 2  Total  HP
# 0      Grass  Poison    318  45
# 1      Grass  Poison    405  60
# 2      Grass  Poison    525  80
# 3      Grass  Poison    625  80
# 4       Fire     NaN    309  39
# ..       ...     ...    ...  ..
# 795     Rock   Fairy    600  50
# 796     Rock   Fairy    700  50
# 797  Psychic   Ghost    600  80
# 798  Psychic    Dark    680  80
# 799     Fire   Water    600  80
#
# [800 rows x 4 columns]

# %%
df.loc[1:5, 'Type 1': 'HP']
# Out:
#   Type 1  Type 2  Total  HP
# 1  Grass  Poison    405  60
# 2  Grass  Poison    525  80
# 3  Grass  Poison    625  80
# 4   Fire     NaN    309  39
# 5   Fire     NaN    405  58

# %%
df.loc[[1, 27, 13], 'Type 1': 'HP']
# Out:
#     Type 1  Type 2  Total  HP
# 1    Grass  Poison    405  60
# 27  Normal  Flying    442  65
# 13     Bug     NaN    195  45

# %%
df.loc[[1, 27, 13], ['Type 1', 'HP']]
# Out:
#     Type 1  HP
# 1    Grass  60
# 27  Normal  65
# 13     Bug  45

# %%
df.iloc[:, 2]
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df.iloc[1:5, 2:5]
# Out:
#   Type 1  Type 2  Total
# 1  Grass  Poison    405
# 2  Grass  Poison    525
# 3  Grass  Poison    625
# 4   Fire     NaN    309

# %%
df.iloc[[13, 27], 2]
# Out:
# 13       Bug
# 27    Normal
# Name: Type 1, dtype: object

# %%
df.set_index('Number')
# Out:
#                          Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# Number
# 1                   Bulbasaur    Grass  Poison    318  45      49       49
# 2                     Ivysaur    Grass  Poison    405  60      62       63
# 3                    Venusaur    Grass  Poison    525  80      82       83
# 3       VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4                  Charmander     Fire     NaN    309  39      52       43
# ...                       ...      ...     ...    ...  ..     ...      ...
# 719                   Diancie     Rock   Fairy    600  50     100      150
# 719       DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720       HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720        HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721                 Volcanion     Fire   Water    600  80     110      120
#
#         Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    Number                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur  Grass  Poison    318  45      49       49
# 1       2                Ivysaur  Grass  Poison    405  60      62       63
# 2       3               Venusaur  Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4       4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.set_index('Number', inplace=True)

# %%
df.head()
# Out:
#                          Name Type 1  Type 2  Total  HP  Attack  Defense  \
# Number
# 1                   Bulbasaur  Grass  Poison    318  45      49       49
# 2                     Ivysaur  Grass  Poison    405  60      62       63
# 3                    Venusaur  Grass  Poison    525  80      82       83
# 3       VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                  Charmander   Fire     NaN    309  39      52       43
#
#         Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Number
# 1            65       65     45           1      False
# 2            80       80     60           1      False
# 3           100      100     80           1      False
# 3           122      120     80           1      False
# 4            60       50     65           1      False

# %%
df.reset_index()
# Out:
#      Number                   Name   Type 1  Type 2  Total  HP  Attack  \
# 0         1              Bulbasaur    Grass  Poison    318  45      49
# 1         2                Ivysaur    Grass  Poison    405  60      62
# 2         3               Venusaur    Grass  Poison    525  80      82
# 3         3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 4         4             Charmander     Fire     NaN    309  39      52
# ..      ...                    ...      ...     ...    ...  ..     ...
# 795     719                Diancie     Rock   Fairy    600  50     100
# 796     719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 797     720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798     720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799     721              Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#                          Name Type 1  Type 2  Total  HP  Attack  Defense  \
# Number
# 1                   Bulbasaur  Grass  Poison    318  45      49       49
# 2                     Ivysaur  Grass  Poison    405  60      62       63
# 3                    Venusaur  Grass  Poison    525  80      82       83
# 3       VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                  Charmander   Fire     NaN    309  39      52       43
#
#         Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Number
# 1            65       65     45           1      False
# 2            80       80     60           1      False
# 3           100      100     80           1      False
# 3           122      120     80           1      False
# 4            60       50     65           1      False

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    Number                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur  Grass  Poison    318  45      49       49
# 1       2                Ivysaur  Grass  Poison    405  60      62       63
# 2       3               Venusaur  Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4       4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
print(df['HP'].max())
print(df['HP'].min())
print(df['HP'].sum())
print(df['HP'].std())
print(df['HP'].var())
# Out:
# 255
# 1
# 55407
# 25.53466903233207
# 652.0193225907384

# %%
df.groupby('Legendary')['HP'].mean()
# Out:
# Legendary
# False    67.182313
# True     92.738462
# Name: HP, dtype: float64

# %%
df.groupby('Legendary')[['Attack', 'Defense']].mean()
# Out:
#                Attack    Defense
# Legendary
# False       75.669388  71.559184
# True       116.676923  99.661538

# %%
df.groupby('Legendary')[['Attack', 'Defense']].agg(['max', 'min'])
# Out:
#           Attack     Defense
#              max min     max min
# Legendary
# False        185   5     230   5
# True         190  50     200  20

# %%
df.groupby('Legendary')[['Attack', 'Defense']].agg({'Attack':'max', 'Defense':'min'})
# Out:
#            Attack  Defense
# Legendary
# False         185        5
# True          190       20

# %%
df.sort_values('HP')
# Out:
#      Number       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316     292   Shedinja      Bug  Ghost    236    1      90       45       30
# 55       50    Diglett   Ground    NaN    265   10      55       25       35
# 139     129   Magikarp    Water    NaN    200   20      10       55       15
# 388     355    Duskull    Ghost    NaN    295   20      40       90       30
# 487     439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# ..      ...        ...      ...    ...    ...  ...     ...      ...      ...
# 655     594  Alomomola    Water    NaN    470  165      75       80       40
# 351     321    Wailord    Water    NaN    500  170      90       45       90
# 217     202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 121     113    Chansey   Normal    NaN    450  250       5        5       35
# 261     242    Blissey   Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('HP', ascending=True)
# Out:
#      Number       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316     292   Shedinja      Bug  Ghost    236    1      90       45       30
# 55       50    Diglett   Ground    NaN    265   10      55       25       35
# 139     129   Magikarp    Water    NaN    200   20      10       55       15
# 388     355    Duskull    Ghost    NaN    295   20      40       90       30
# 487     439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# ..      ...        ...      ...    ...    ...  ...     ...      ...      ...
# 655     594  Alomomola    Water    NaN    470  165      75       80       40
# 351     321    Wailord    Water    NaN    500  170      90       45       90
# 217     202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 121     113    Chansey   Normal    NaN    450  250       5        5       35
# 261     242    Blissey   Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('HP', ascending=False)
# Out:
#      Number       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261     242    Blissey   Normal    NaN    540  255      10       10       75
# 121     113    Chansey   Normal    NaN    450  250       5        5       35
# 217     202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 351     321    Wailord    Water    NaN    500  170      90       45       90
# 655     594  Alomomola    Water    NaN    470  165      75       80       40
# ..      ...        ...      ...    ...    ...  ...     ...      ...      ...
# 139     129   Magikarp    Water    NaN    200   20      10       55       15
# 381     349     Feebas    Water    NaN    200   20      15       20       10
# 388     355    Duskull    Ghost    NaN    295   20      40       90       30
# 55       50    Diglett   Ground    NaN    265   10      55       25       35
# 316     292   Shedinja      Bug  Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['HP', 'Attack'], ascending=[True, False])
# Out:
#      Number       Name    Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316     292   Shedinja       Bug  Ghost    236    1      90       45       30
# 55       50    Diglett    Ground    NaN    265   10      55       25       35
# 186     172      Pichu  Electric    NaN    205   20      40       15       35
# 388     355    Duskull     Ghost    NaN    295   20      40       90       30
# 487     439   Mime Jr.   Psychic  Fairy    310   20      25       45       70
# ..      ...        ...       ...    ...    ...  ...     ...      ...      ...
# 655     594  Alomomola     Water    NaN    470  165      75       80       40
# 351     321    Wailord     Water    NaN    500  170      90       45       90
# 217     202  Wobbuffet   Psychic    NaN    405  190      33       58       33
# 121     113    Chansey    Normal    NaN    450  250       5        5       35
# 261     242    Blissey    Normal    NaN    540  255      10       10       75
#
# ...

# %%
df.isnull().sum()
# Out:
# Number          0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df['Type 2'].mode()
# Out:
# 0    Flying
# dtype: object

# %%
df['Type 2'].mode()[0]
# Out:
# 'Flying'

# %%
df['Type 2'].fillna(df['Type 2'].mode()[0], inplace=True)

# %%
df.head()
# Out:
#    Number                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur  Grass  Poison    318  45      49       49
# 1       2                Ivysaur  Grass  Poison    405  60      62       63
# 2       3               Venusaur  Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4       4             Charmander   Fire  Flying    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 1'].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=(12, 8))
df['Type 1'].value_counts().plot.bar()
plt.show()

# %%
plt.figure(figsize=(12, 8))
df['Type 1'].value_counts().plot.bar()
plt.xticks(rotation=45)
plt.show()

# %%
df.nunique()
# Out:
# Number        721
# Name          800
# Type 1         18
# Type 2         18
# Total         200
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type 1'].nunique()
# Out:
# 18

# %%
df._get_numeric_data()
# Out:
#      Number  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0         1    318  45      49       49       65       65     45           1
# 1         2    405  60      62       63       80       80     60           1
# 2         3    525  80      82       83      100      100     80           1
# 3         3    625  80     100      123      122      120     80           1
# 4         4    309  39      52       43       60       50     65           1
# ..      ...    ...  ..     ...      ...      ...      ...    ...         ...
# 795     719    600  50     100      150      100      150     50           6
# 796     719    700  50     160      110      160      110    110           6
# 797     720    600  80     110       60      150      130     70           6
# 798     720    680  80     160       60      170      130     80           6
# 799     721    600  80     110      120      130       90     70           6
#
#      Legendary
# 0        False
# ...

# %%
num_cols=df._get_numeric_data().columns
print(num_cols)
# Out:
# Index(['Number', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def',
#        'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.select_dtypes(include=['object'])
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire  Flying
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
cat_cols=list(set(df.columns)-set(num_cols))

print(cat_cols)
# Out:
# ['Name', 'Type 2', 'Type 1']

# %%
sns.boxplot(df['HP'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(x='Legendary', y='HP', data=df)
plt.show()

# %%
sns.scatterplot(x='Attack', y='Defense', data=df)

# %%
sns.scatterplot(x='Attack', y='Defense', hue='Legendary', data=df)

# %%
df['Legendary']=df['Legendary'].astype(int)

# %%
df.head()
# Out:
#    Number                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur  Grass  Poison    318  45      49       49
# 1       2                Ivysaur  Grass  Poison    405  60      62       63
# 2       3               Venusaur  Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4       4             Charmander   Fire  Flying    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1          0
# 1       80       80     60           1          0
# 2      100      100     80           1          0
# 3      122      120     80           1          0
# 4       60       50     65           1          0

# %%
df.drop('Number', axis=1)
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire  Flying    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head()
# Out:
#    Number                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur  Grass  Poison    318  45      49       49
# 1       2                Ivysaur  Grass  Poison    405  60      62       63
# 2       3               Venusaur  Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4       4             Charmander   Fire  Flying    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1          0
# 1       80       80     60           1          0
# 2      100      100     80           1          0
# 3      122      120     80           1          0
# 4       60       50     65           1          0

# %%
df.drop('Number', axis=1, inplace=True)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire  Flying    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1          0
# 1       80     60           1          0
# 2      100     80           1          0
# 3      120     80           1          0
# 4       50     65           1          0

# %%
df.drop([1, 3], axis=0)
# Out:
#                     Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0              Bulbasaur    Grass  Poison    318  45      49       49
# 2               Venusaur    Grass  Poison    525  80      82       83
# 4             Charmander     Fire  Flying    309  39      52       43
# 5             Charmeleon     Fire  Flying    405  58      64       58
# 6              Charizard     Fire  Flying    534  78      84       78
# ..                   ...      ...     ...    ...  ..     ...      ...
# 795              Diancie     Rock   Fairy    600  50     100      150
# 796  DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1          0
# ...

# %%
df.drop([1, 3])
# Out:
#                     Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0              Bulbasaur    Grass  Poison    318  45      49       49
# 2               Venusaur    Grass  Poison    525  80      82       83
# 4             Charmander     Fire  Flying    309  39      52       43
# 5             Charmeleon     Fire  Flying    405  58      64       58
# 6              Charizard     Fire  Flying    534  78      84       78
# ..                   ...      ...     ...    ...  ..     ...      ...
# 795              Diancie     Rock   Fairy    600  50     100      150
# 796  DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1          0
# ...
